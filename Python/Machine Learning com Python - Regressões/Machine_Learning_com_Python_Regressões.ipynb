# %% [markdown]
# # Machine Learning com Python - Regressões

# %% [markdown]
# # Regressão linear simples

# %% [markdown]
# ## Base plano saúde

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)

# %%
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
base_plano_saude = pd.read_csv('plano_saude.csv')
base_plano_saude
# Out:
#    idade  custo
# 0     18    871
# 1     23   1132
# 2     28   1242
# 3     33   1356
# 4     38   1488
# 5     43   1638
# 6     48   2130
# 7     53   2454
# 8     58   3066
# 9     63   4090

# %%
X_plano_saude = base_plano_saude.iloc[:, 0].values
X_plano_saude
# Out:
# array([18, 23, 28, 33, 38, 43, 48, 53, 58, 63])

# %%
y_plano_saude = base_plano_saude.iloc[:, 1].values
y_plano_saude
# Out:
# array([ 871, 1132, 1242, 1356, 1488, 1638, 2130, 2454, 3066, 4090])

# %%
np.corrcoef(X_plano_saude, y_plano_saude)
# Out:
# array([[1.        , 0.93091958],
#        [0.93091958, 1.        ]])

# %%
X_plano_saude.shape
# Out:
# (10,)

# %%
X_plano_saude = X_plano_saude.reshape(-1,1)
X_plano_saude.shape
# Out:
# (10, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor_plano_saude = LinearRegression()
regressor_plano_saude.fit(X_plano_saude, y_plano_saude)
# Out:
# LinearRegression()

# %%
# b0
regressor_plano_saude.intercept_
# Out:
# -558.9490909090912

# %%
# b1
regressor_plano_saude.coef_
# Out:
# array([61.86787879])

# %%
previsoes = regressor_plano_saude.predict(X_plano_saude)
previsoes
# Out:
# array([ 554.67272727,  864.01212121, 1173.35151515, 1482.69090909,
#        1792.03030303, 2101.36969697, 2410.70909091, 2720.04848485,
#        3029.38787879, 3338.72727273])

# %%
X_plano_saude.ravel()
# Out:
# array([18, 23, 28, 33, 38, 43, 48, 53, 58, 63])

# %%
grafico = px.scatter(x = X_plano_saude.ravel(), y = y_plano_saude)
grafico.add_scatter(x = X_plano_saude.ravel(), y = previsoes, name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b717ac47-bab5-4832-bd8e-00a95970d359" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b717ac47-bab5-4832-bd8e-00a95970d359")) {                    Plotly.newPlot(                        "b717ac47-bab5-4832-bd8e-00a95970d359",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[871,1132,1242,1356,1488,1638,2130,2454,3066,4090],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[554.6727272727271,864.012121212121,1173.351515151515,1482.6909090909091,1792.0303030303028,2101.3696969696966,2410.709090909091,2720.048484848485,3029.3878787878793,3338.727272727273],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3 ...

# %%
regressor_plano_saude.intercept_ + regressor_plano_saude.coef_ * 40
# Out:
# array([1915.76606061])

# %%
regressor_plano_saude.predict([[40]])
# Out:
# array([1915.76606061])

# %%
regressor_plano_saude.score(X_plano_saude, y_plano_saude)
# Out:
# 0.8666112727879174

# %%
from yellowbrick.regressor import ResidualsPlot
visualizador = ResidualsPlot(regressor_plano_saude)
visualizador.fit(X_plano_saude, y_plano_saude)
visualizador.poof()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ## Base preço das casas - MAE 172.604, 0.48

# %%
base_casas = pd.read_csv('house_prices.csv')
base_casas
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
base_casas.drop('date', axis=1, inplace=True)

# %%
base_casas.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
base_casas.isnull().sum()
# Out:
# id               0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
base_casas.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# sqft_above    -0.010842  0.605567  0.477600   0.685342     0.876597  0.183512
# sqft_basement -0.005151  0.323816  0.303093   0.283770     0.435043  0.015286
# yr_built       0.021380  0.054012  0.154178   0.506019     0.318049  0.053080
# yr_renovated  -0.016907  0.126434  0.018841   0.050739     0.055363  0.007644
# zipcode       -0.008224 -0.053203 -0.152668  -0.203866    -0.199430 -0.129574
# lat           -0.001891  0.307003 -0.008931   0.024573     0.052529 -0.085683
# long           0.020799  0.021626  0.129473   0.223042     0.240223  0.229521
# sqft_living15 -0.002901  0.585379  0.391638   0.568634     0.756420  0.144608
# sqft_lot15    -0.138798  0.082447  0.029244   0.087175     0.183286  0.718557
#
#                  floors  waterfront      view  condition     grade  \
# id             0.018525   -0.002721  0.011592  -0.023783  0.008130
# price          0.256794    0.266369  0.397293   0.036362  0.667434
# bedrooms       0.175429   -0.006582  0.079532   0.028472  0.356967
# bathrooms      0.500653    0.063744  0.187737  -0.124982  0.664983
# sqft_living    0.353949    0.103818  0.284611  -0.058753  0.762704
# sqft_lot      -0.005201    0.021604  0.074710  -0.008958  0.113621
# floors         1.000000    0.023698  0.029444  -0.263768  0.458183
# waterfront     0.023698    1.000000  0.401857   0.016653  0.082775
# view           0.029444    0.401857  1.000000   0.045990  0.251321
# condition     -0.263768    0.016653  0.045990   1.000000 -0.144674
# grade          0.458183    0.082775  0.251321  -0.144674  1.000000
# sqft_above     0.523885    0.072075  0.167649  -0.158214  0.755923
# sqft_basement -0.245705    0.080588  0.276947   0.174105  0.168392
# yr_built       0.489319   -0.026161 -0.053440  -0.361417  0.446963
# yr_renovated   0.006338    0.092885  0.103917  -0.060618  0.014414
# zipcode       -0.059121    0.030285  0.084827   0.003026 -0.184862
# lat            0.049614   -0.014274  0.006157  -0.014941  0.114084
# long           0.125419   -0.041910 -0.078400  -0.106500  0.198372
# sqft_living15  0.279885    0.086463  0.280439  -0.092824  0.713202
# sqft_lot15    -0.011269    0.030703  0.072575  -0.003406  0.119248
#
#                sqft_above  sqft_basement  yr_built  yr_renovated   zipcode  \
# id              -0.010842      -0.005151  0.021380     -0.016907 -0.008224
# price            0.605567       0.323816  0.054012      0.126434 -0.053203
# bedrooms         0.477600       0.303093  0.154178      0.018841 -0.152668
# bathrooms        0.685342       0.283770  0.506019      0.050739 -0.203866
# sqft_living      0.876597       0.435043  0.318049      0.055363 -0.199430
# sqft_lot         0.183512       0.015286  0.053080      0.007644 -0.129574
# floors           0.523885      -0.245705  0.489319      0.006338 -0.059121
# waterfront       0.072075       0.080588 -0.026161      0.092885  0.030285
# view             0.167649       0.276947 -0.053440      0.103917  0.084827
# condition       -0.158214       0.174105 -0.361417     -0.060618  0.003026
# grade            0.755923       0.168392  0.446963      0.014414 -0.184862
# sqft_above       1.000000      -0.051943  0.423898      0.023285 -0.261190
# sqft_basement   -0.051943       1.000000 -0.133124      0.071323  0.074845
# yr_built         0.423898      -0.133124  1.000000     -0.224874 -0.346869
# yr_renovated     0.023285       0.071323 -0.224874      1.000000  0.064357
# zipcode         -0.261190       0.074845 -0.346869      0.064357  1.000000
# lat             -0.000816       0.110538 -0.148122      0.029398  0.267048
# long             0.343803      -0.144765  0.409356     -0.068372 -0.564072
# sqft_living15    0.731870       0.200355  0.326229     -0.002673 -0.279033
# sqft_lot15       0.194050       0.017276  0.070958      0.007854 -0.147221
#
#                     lat      long  sqft_living15  sqft_lot15
# id            -0.001891  0.020799      -0.002901   -0.138798
# price          0.307003  0.021626       0.585379    0.082447
# bedrooms      -0.008931  0.129473       0.391638    0.029244
# bathrooms      0.024573  0.223042       0.568634    0.087175
# sqft_living    0.052529  0.240223       0.756420    0.183286
# sqft_lot      -0.085683  0.229521       0.144608    0.718557
# floors         0.049614  0.125419       0.279885   -0.011269
# waterfront    -0.014274 -0.041910       0.086463    0.030703
# view           0.006157 -0.078400       0.280439    0.072575
# condition     -0.014941 -0.106500      -0.092824   -0.003406
# grade          0.114084  0.198372       0.713202    0.119248
# sqft_above    -0.000816  0.343803       0.731870    0.194050
# sqft_basement  0.110538 -0.144765       0.200355    0.017276
# yr_built      -0.148122  0.409356       0.326229    0.070958
# yr_renovated   0.029398 -0.068372      -0.002673    0.007854
# zipcode        0.267048 -0.564072      -0.279033   -0.147221
# lat            1.000000 -0.135512       0.048858   -0.086419
# long          -0.135512  1.000000       0.334605    0.254451
# sqft_living15  0.048858  0.334605       1.000000    0.183192
# sqft_lot15    -0.086419  0.254451       0.183192    1.000000

# %%
figura = plt.figure(figsize=(20,20))
sns.heatmap(base_casas.corr(), annot=True);

# %%
X_casas = base_casas.iloc[:,5:6].values
X_casas
# Out:
# array([[ 5650],
#        [ 7242],
#        [10000],
#        ...,
#        [ 1350],
#        [ 2388],
#        [ 1076]])

# %%
y_casas = base_casas.iloc[:, 2].values
y_casas
# Out:
# array([3, 3, 2, ..., 2, 3, 2])

# %%
from sklearn.model_selection import train_test_split
X_casas_treinamento, X_casas_teste, y_casas_treinamento, y_casas_teste = train_test_split(X_casas, y_casas, test_size = 0.3, random_state = 0)

# %%
X_casas_treinamento.shape, y_casas_treinamento.shape
# Out:
# ((15129, 1), (15129,))

# %%
X_casas_teste.shape, y_casas_teste.shape
# Out:
# ((6484, 1), (6484,))

# %%
from sklearn.linear_model import LinearRegression
regressor_simples_casas = LinearRegression()
regressor_simples_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
# b0
regressor_simples_casas.intercept_
# Out:
# 3.355183935781682

# %%
# b1
regressor_simples_casas.coef_
# Out:
# array([6.79426782e-07])

# %%
regressor_simples_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.000920509971809147

# %%
regressor_simples_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.0008220249628060339

# %%
previsoes = regressor_simples_casas.predict(X_casas_treinamento)
previsoes
# Out:
# array([3.36007581, 3.36015462, 3.35883857, ..., 3.36534137, 3.40727219,
#        3.36621511])

# %%
grafico = px.scatter(x = X_casas_treinamento.ravel(), y = previsoes)
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="01aaddfe-075f-4f69-b7fd-724d51db7ed5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01aaddfe-075f-4f69-b7fd-724d51db7ed5")) {                    Plotly.newPlot(                        "01aaddfe-075f-4f69-b7fd-724d51db7ed5",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[7200,7316,5379,4125,57000,5100,7200,12138,7350,7800,4385,3080,1294,4120,6000,12675,4000,8282,15300,9652,7500,17300,9310,5393,7153,7560,4871,4930,5283,12350,2067,4284,19405,7500,5632,9000,800,8250,18500,4000,1848,12875,6899,4840,24330,3090,3515,7280,9600,3368,9800,8580,8732,1348,4443,62310,8720,6082,50654,8528,5913,11904,8250,9230,4040,20925,8244,7344,5200,12812,2689,8893,16800,6359,15365,9780,5000,4000,9525,9000,4667,6240,50308,5000,6156,3218,11770,7261,6867,7615,1562,16000,22334,47044,11590,5140,10250,8925,5000,6860,26540,10000,11350,2786,5600,9382,93218,70567,14972,7590,8378,7245,5120,4000,5000,7000,7598,8750,21780,13235,12462,43124,7649,5700,1682,10000,74297,12327,23809,7125,5600,13775,7200,9726,6000,7543,392475,1619,7100,8640,48693,12201,6702,2030,7129,14219,2814,9600,15093,12825,3129,6624,4400,3000,5100,3072,4931,8364,1204,7220,6000,6739,44947,8282,1856,7380,7599,24237,4076,7451,3000,6600,4759,7623,4932,2820,18731,3141,8065,1036,9200,9917,22725,12155,8850,52983,4080,3841,208652,7200,9975,3671,4800,2970,16288,704,5385,5000,35440,9753,5000,49542,7344,9686,4459,1676,11171,6360,6400,4838,6400,6052,5250,1588,6240,12282,6460,4500,3150,10344,7650,10433,4800,3180,52595,7085,10335,7225,3873,219527,10559,189486,7838,12800,11963,4275,3795,9083,8594,6000,9715,10920,4400,7282,5200,1587,10588,2550,7740,11070,6000,5340,6003,7155,20785,35070,3740,4800,9639,9300,8263,15175,6250,432036,1126,10510,6360,4000,7200,8127,13356,7650,4500,6000,10664,18557,902,7560,10358,746,9916,6100,1020,11000,147823,19607,23660,4500,41250,8000,7679,8750,3333,6000,87991,7232,8536,8480,7950,8174,4750,6684,2625,174240,3600,6744,38012,5874,7200,6780,10466,37034,31941,8970,5683,8100,9248,5700,7896,9195,9480,7081,15000,9653,7500,9000,4000,4120,13650,5000,4960,7200,8360,4185,3850,8433,16549,6388,4725,8100,10249,1101,5000,7200,4500,13000,15219,5505,7400,14690,1194,8249,6827,8400,8301,27806,7500,13300,8521,8200,26051,9135,8108,46609,1340,23000,8400,7592,13885,871,4744,18099,5737,5723,4500,5750,10155,8184,9040,9935,1899,8480,5000,8040,21883,6825,2554,3500,7207,4650,7770,3600,10960,13782,9600,22653,10431,1140,10450,39446,4000,6075,1189,6000,3300,7722,54059,7104,7260,8320,8625,5500,6134,6800,8627,15724,7735,7000,10089,7200,7533,8400,5000,13300,13093,7986,11616,9010,11996,9652,16524,7770,6000,8033,5800,2000,5115,19225,6519,14985,5720,1265,8025,11799,4000,5674,10560,7300,3090,42000,2250,9000,7202,7639,5831,11675,262666,7535,5802,9938,7772,814,6551,1064,12500,8821,8509,5331,6380,16110,7155,7500,4011,3800,9628,11250,6555,5250,74487,1372,8581,4904,28243,9921,7800,47916,5647,10925,3438,3000,6134,8000,43560,24550,11254,5570,8684,3748,7205,49223,7210,6973,5200,4000,6481,2688,7675,18618,11422,3750,7540,9987,8700,7642,9600,7133,2287,6000,8000,5001,9200,12188,4108,10603,422967,5000,1310,23030,7400,7546,8479,5412,10480,7200,9972,1256,6380,1486,15360,16617,3777,16065,4190,6736,15600,8290,5100,7434,6000,8040,25020,1490,13736,8035,6150,1031,199253,19271,1118,7500,16480,10501,4666,27600,11805,5500,6130,3900,7207,8165,55387,4900,8060,78225,4440,7386,6535,39370,3624,9525,4441,10018,8000,11975,5000,6840,8335,6642,9775,98445,12095,4800,4800,1950,7110,3800,7245,4090,8187,5720,1500,4080,16921,79279,9525,10390,1253,7200,11651,7740,8401,10790,516 ...

# %%
grafico1 = px.scatter(x = X_casas_treinamento.ravel(), y = y_casas_treinamento)
grafico2 = px.line(x = X_casas_treinamento.ravel(), y = previsoes)
grafico2.data[0].line.color = 'red'
grafico3 = go.Figure(data=grafico1.data + grafico2.data)
grafico3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eac79ad1-3206-42aa-8f1d-90036c706144" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eac79ad1-3206-42aa-8f1d-90036c706144")) {                    Plotly.newPlot(                        "eac79ad1-3206-42aa-8f1d-90036c706144",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[7200,7316,5379,4125,57000,5100,7200,12138,7350,7800,4385,3080,1294,4120,6000,12675,4000,8282,15300,9652,7500,17300,9310,5393,7153,7560,4871,4930,5283,12350,2067,4284,19405,7500,5632,9000,800,8250,18500,4000,1848,12875,6899,4840,24330,3090,3515,7280,9600,3368,9800,8580,8732,1348,4443,62310,8720,6082,50654,8528,5913,11904,8250,9230,4040,20925,8244,7344,5200,12812,2689,8893,16800,6359,15365,9780,5000,4000,9525,9000,4667,6240,50308,5000,6156,3218,11770,7261,6867,7615,1562,16000,22334,47044,11590,5140,10250,8925,5000,6860,26540,10000,11350,2786,5600,9382,93218,70567,14972,7590,8378,7245,5120,4000,5000,7000,7598,8750,21780,13235,12462,43124,7649,5700,1682,10000,74297,12327,23809,7125,5600,13775,7200,9726,6000,7543,392475,1619,7100,8640,48693,12201,6702,2030,7129,14219,2814,9600,15093,12825,3129,6624,4400,3000,5100,3072,4931,8364,1204,7220,6000,6739,44947,8282,1856,7380,7599,24237,4076,7451,3000,6600,4759,7623,4932,2820,18731,3141,8065,1036,9200,9917,22725,12155,8850,52983,4080,3841,208652,7200,9975,3671,4800,2970,16288,704,5385,5000,35440,9753,5000,49542,7344,9686,4459,1676,11171,6360,6400,4838,6400,6052,5250,1588,6240,12282,6460,4500,3150,10344,7650,10433,4800,3180,52595,7085,10335,7225,3873,219527,10559,189486,7838,12800,11963,4275,3795,9083,8594,6000,9715,10920,4400,7282,5200,1587,10588,2550,7740,11070,6000,5340,6003,7155,20785,35070,3740,4800,9639,9300,8263,15175,6250,432036,1126,10510,6360,4000,7200,8127,13356,7650,4500,6000,10664,18557,902,7560,10358,746,9916,6100,1020,11000,147823,19607,23660,4500,41250,8000,7679,8750,3333,6000,87991,7232,8536,8480,7950,8174,4750,6684,2625,174240,3600,6744,38012,5874,7200,6780,10466,37034,31941,8970,5683,8100,9248,5700,7896,9195,9480,7081,15000,9653,7500,9000,4000,4120,13650,5000,4960,7200,8360,4185,3850,8433,16549,6388,4725,8100,10249,1101,5000,7200,4500,13000,15219,5505,7400,14690,1194,8249,6827,8400,8301,27806,7500,13300,8521,8200,26051,9135,8108,46609,1340,23000,8400,7592,13885,871,4744,18099,5737,5723,4500,5750,10155,8184,9040,9935,1899,8480,5000,8040,21883,6825,2554,3500,7207,4650,7770,3600,10960,13782,9600,22653,10431,1140,10450,39446,4000,6075,1189,6000,3300,7722,54059,7104,7260,8320,8625,5500,6134,6800,8627,15724,7735,7000,10089,7200,7533,8400,5000,13300,13093,7986,11616,9010,11996,9652,16524,7770,6000,8033,5800,2000,5115,19225,6519,14985,5720,1265,8025,11799,4000,5674,10560,7300,3090,42000,2250,9000,7202,7639,5831,11675,262666,7535,5802,9938,7772,814,6551,1064,12500,8821,8509,5331,6380,16110,7155,7500,4011,3800,9628,11250,6555,5250,74487,1372,8581,4904,28243,9921,7800,47916,5647,10925,3438,3000,6134,8000,43560,24550,11254,5570,8684,3748,7205,49223,7210,6973,5200,4000,6481,2688,7675,18618,11422,3750,7540,9987,8700,7642,9600,7133,2287,6000,8000,5001,9200,12188,4108,10603,422967,5000,1310,23030,7400,7546,8479,5412,10480,7200,9972,1256,6380,1486,15360,16617,3777,16065,4190,6736,15600,8290,5100,7434,6000,8040,25020,1490,13736,8035,6150,1031,199253,19271,1118,7500,16480,10501,4666,27600,11805,5500,6130,3900,7207,8165,55387,4900,8060,78225,4440,7386,6535,39370,3624,9525,4441,10018,8000,11975,5000,6840,8335,6642,9775,98445,12095,4800,4800,1950,7110,3800,7245,4090,8187,5720,1500,4080,16921,79279,9525,10390,1253,7200,11651,7740,8401,10790,516 ...

# %%
previsoes_teste = regressor_simples_casas.predict(X_casas_teste)
previsoes_teste
# Out:
# array([3.35630499, 3.3904027 , 3.35769781, ..., 3.3726486 , 3.36062546,
#        3.36146116])

# %%
y_casas_teste
# Out:
# array([2, 4, 2, ..., 3, 3, 3])

# %%
abs(y_casas_teste - previsoes_teste).mean()
# Out:
# 0.7217139313807803

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_casas_teste, previsoes_teste)
# Out:
# 0.7217139313807803

# %%
mean_squared_error(y_casas_teste, previsoes_teste)
# Out:
# 0.8004859591383177

# %%
np.sqrt(mean_squared_error(y_casas_teste, previsoes_teste))
# Out:
# 0.8946988091745276

# %%
grafico1 = px.scatter(x = X_casas_teste.ravel(), y = y_casas_teste)
grafico2 = px.line(x = X_casas_teste.ravel(), y = previsoes_teste)
grafico2.data[0].line.color = 'red'
grafico3 = go.Figure(data=grafico1.data + grafico2.data)
grafico3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="94d4eb39-2d51-4ef9-8147-1900858c08a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94d4eb39-2d51-4ef9-8147-1900858c08a6")) {                    Plotly.newPlot(                        "94d4eb39-2d51-4ef9-8147-1900858c08a6",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[1650,51836,3700,2640,9603,3436,28000,4600,5440,2975,11300,3581,1049,11744,10105,2268,3056,2620,12724,7200,7740,8450,9077,9452,15200,5132,7816,7194,8700,6010,3128,6200,43560,9000,13720,16300,1270,8076,105587,7486,11862,60984,6975,7945,8140,10083,6000,12792,6840,47502,7480,10794,20158,9600,24604,5100,1279,7900,3200,4025,1150,7007,2560,6000,6010,9525,4714,10086,3997,8925,9742,5920,3750,7599,52953,42717,16387,9760,17409,9139,3667,4452,22710,161607,8127,2551,5401,13115,6120,7486,68257,4819,9966,4322,18851,2040,12134,49044,8503,4838,9120,4600,4945,13000,8534,6796,9874,5500,4590,8867,5405,10257,7515,5471,5812,39960,3172,8160,3600,9437,8000,6773,3700,25245,929,8470,5240,4080,5214,4500,23994,4800,8340,9600,15950,7700,5700,7670,22326,12044,35362,8175,12063,8505,9645,5539,8100,11600,5616,1400,6765,8967,1213,7264,7439,3118,7759,7869,1222,3721,7875,16015,7200,2875,4667,9658,7175,374616,7140,8400,10854,7414,10344,8750,4000,8950,5280,11547,5200,4500,4000,5038,11173,4656,5379,8641,8100,108464,8118,212137,7000,5150,11942,5250,8540,6928,8056,6840,4274,50094,2656,7500,4420,52707,11900,6000,33980,8625,5030,9091,6752,7400,9750,4508,7200,15685,8378,38865,7912,4579,7947,35001,13425,7135,4000,8800,7320,5200,7200,4000,6977,6998,11965,9772,7680,4500,3211,2850,8505,2128,4799,50002,12409,1851,9800,3021,9263,7700,8125,73616,4054,4200,32757,2052,9681,6092,2500,7213,9600,4750,12750,11536,8050,8560,8400,6305,3600,4583,8068,7575,1103,6479,10929,1754,6400,11393,7768,14190,3917,5600,8944,9030,14322,33042,74052,6828,6980,6060,15044,1991,4080,3893,7719,28000,6653,4200,20720,5692,9389,3600,9750,8520,5544,6356,231739,31510,9830,7800,10633,263538,3330,8040,3600,5000,7350,18255,257875,10270,4620,10416,7488,4080,4526,4751,5336,8764,9985,6000,22072,1863,218506,11189,4815,19865,4000,6771,3604,8116,5608,8860,15909,9450,12142,18707,7980,4364,6507,7200,4800,9240,5200,80400,11461,6200,18129,49375,8400,7560,4997,8775,35183,5000,6250,10639,5100,7642,8504,2800,9889,5800,4667,11902,2839,14890,4668,6200,17172,8010,4120,5688,15899,10513,5054,11985,10205,1822,6664,9750,5000,5200,3775,9292,4750,7521,10155,21540,6582,6000,21318,16001,10080,5649,9601,7200,9953,7840,20750,6452,10125,11441,3243,2167,7000,7110,6000,7209,4874,5217,6930,6944,11603,11556,3000,5000,9956,6000,3323,17674,5101,5598,5250,5546,4800,12368,3676,7344,2868,43088,6250,1078,1526,4203,6591,9000,9778,217800,5000,6300,8706,4000,15239,4400,18055,10332,8252,1312,7204,8400,18843,8864,8400,3920,5082,9226,7471,6840,4308,1234,10860,8342,1722,11780,19800,8540,6200,7500,7500,8366,5100,9008,7210,22873,6930,21275,1709,136915,1399,10500,4120,8771,6400,3855,7950,79279,89651,113862,11250,6600,4399,9800,8737,14161,8501,6530,4760,7544,20672,5111,5355,5922,3400,6791,12696,7510,3708,9600,7361,5000,22215,11200,8120,10190,155130,7220,7700,10855,4683,8028,10500,3821,22111,8268,5000,6954,6000,286181,7200,3930,6300,7916,4467,18029,6037,10608,9425,9566,5500,3880,52889,8960,12518,4100,1180,10630,21937,5250,7885,6120,12375,1005,1558,3838,6441,4088,6099,11040,7620,6010,27350,7200,8400,6320,7684,5085,7866,6120,6380,6000,8120,9066,9600,5490,12384,7300,6666,6775,12353,6079,18599,8320,13591,11250,8000,6371,10160,7242,3588,1803,13200,9500,5100,6039,21701,9473,6450,5120,8300,7352,4046,11120,4102,8738,4 ...

# %% [markdown]
# # Regressão linear múltipla

# %% [markdown]
# ## Base preço das casas - MAE 123.888, 0.68

# %%
base_casas
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0           0     0          3      7        1180              0
# 1         2.0           0     0          3      7        2170            400
# 2         1.0           0     0          3      6         770              0
# 3         1.0           0     0          5      7        1050            910
# 4         1.0           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 20 columns]

# %%
X_casas = base_casas.iloc[:, 3:19].values
X_casas
# Out:
# array([[ 1.00000e+00,  1.18000e+03,  5.65000e+03, ...,  4.75112e+01,
#         -1.22257e+02,  1.34000e+03],
#        [ 2.25000e+00,  2.57000e+03,  7.24200e+03, ...,  4.77210e+01,
#         -1.22319e+02,  1.69000e+03],
#        [ 1.00000e+00,  7.70000e+02,  1.00000e+04, ...,  4.77379e+01,
#         -1.22233e+02,  2.72000e+03],
#        ...,
#        [ 7.50000e-01,  1.02000e+03,  1.35000e+03, ...,  4.75944e+01,
#         -1.22299e+02,  1.02000e+03],
#        [ 2.50000e+00,  1.60000e+03,  2.38800e+03, ...,  4.75345e+01,
#         -1.22069e+02,  1.41000e+03],
#        [ 7.50000e-01,  1.02000e+03,  1.07600e+03, ...,  4.75941e+01,
#         -1.22299e+02,  1.02000e+03]])

# %%
y_casas = base_casas.iloc[:, 2].values
y_casas
# Out:
# array([3, 3, 2, ..., 2, 3, 2])

# %%
from sklearn.model_selection import train_test_split
X_casas_treinamento, X_casas_teste, y_casas_treinamento, y_casas_teste = train_test_split(X_casas, y_casas, test_size = 0.3, random_state = 0)

# %%
X_casas_treinamento.shape, X_casas_teste.shape
# Out:
# ((15129, 16), (6484, 16))

# %%
regressor_multiplo_casas = LinearRegression()
regressor_multiplo_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
regressor_multiplo_casas.intercept_
# Out:
# 81.35599994951795

# %%
regressor_multiplo_casas.coef_
# Out:
# array([ 3.40168475e-01,  4.04400641e-04, -1.41708149e-06, -4.66608213e-02,
#        -4.16007891e-01, -8.90480934e-02,  5.43724979e-02, -1.45010063e-01,
#         1.83085357e-04,  2.21315284e-04, -2.30619947e-03, -5.20881810e-05,
#        -7.92854871e-04, -1.73729715e-01, -9.58217567e-02, -1.94871400e-05])

# %%
len(regressor_multiplo_casas.coef_)
# Out:
# 16

# %%
regressor_multiplo_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.3911299083979677

# %%
regressor_multiplo_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.3985615256409738

# %%
previsoes = regressor_multiplo_casas.predict(X_casas_teste)
previsoes
# Out:
# array([2.70251894, 4.57515624, 2.77900062, ..., 3.65848588, 3.09187509,
#        2.76556214])

# %%
y_casas_teste
# Out:
# array([2, 4, 2, ..., 3, 3, 3])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 0.5275996524121869

# %% [markdown]
# # Regressão polinomial

# %% [markdown]
# ## Base plano de saúde

# %%
base_plano_saude2 = pd.read_csv('plano_saude2.csv')
base_plano_saude2
# Out:
#    idade  custo
# 0     18    470
# 1     23    520
# 2     28    630
# 3     33    830
# 4     38   1150
# 5     43   1530
# 6     48   2040
# 7     53   3080
# 8     58   5100
# 9     63  10100

# %%
X_plano_saude2 = base_plano_saude2.iloc[:, 0:1].values
y_plano_saude2 = base_plano_saude2.iloc[:, 1].values

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 4)
X_plano_saude2_poly = poly.fit_transform(X_plano_saude2)

# %%
X_plano_saude2_poly.shape
# Out:
# (10, 5)

# %%
18 * 18, 18 * 18 * 18, 18 * 18 * 18 * 18
# Out:
# (324, 5832, 104976)

# %%
X_plano_saude2_poly[0]
# Out:
# array([1.00000e+00, 1.80000e+01, 3.24000e+02, 5.83200e+03, 1.04976e+05])

# %%
23 * 23
# Out:
# 529

# %%
X_plano_saude2_poly[1]
# Out:
# array([1.00000e+00, 2.30000e+01, 5.29000e+02, 1.21670e+04, 2.79841e+05])

# %%
X_plano_saude2_poly
# Out:
# array([[1.0000000e+00, 1.8000000e+01, 3.2400000e+02, 5.8320000e+03,
#         1.0497600e+05],
#        [1.0000000e+00, 2.3000000e+01, 5.2900000e+02, 1.2167000e+04,
#         2.7984100e+05],
#        [1.0000000e+00, 2.8000000e+01, 7.8400000e+02, 2.1952000e+04,
#         6.1465600e+05],
#        [1.0000000e+00, 3.3000000e+01, 1.0890000e+03, 3.5937000e+04,
#         1.1859210e+06],
#        [1.0000000e+00, 3.8000000e+01, 1.4440000e+03, 5.4872000e+04,
#         2.0851360e+06],
#        [1.0000000e+00, 4.3000000e+01, 1.8490000e+03, 7.9507000e+04,
#         3.4188010e+06],
#        [1.0000000e+00, 4.8000000e+01, 2.3040000e+03, 1.1059200e+05,
#         5.3084160e+06],
#        [1.0000000e+00, 5.3000000e+01, 2.8090000e+03, 1.4887700e+05,
#         7.8904810e+06],
#        [1.0000000e+00, 5.8000000e+01, 3.3640000e+03, 1.9511200e+05,
#         1.1316496e+07],
#        [1.0000000e+00, 6.3000000e+01, 3.9690000e+03, 2.5004700e+05,
#         1.5752961e+07]])

# %%
regressor_saude_polinomial = LinearRegression()
regressor_saude_polinomial.fit(X_plano_saude2_poly, y_plano_saude2)
# Out:
# LinearRegression()

# %%
# b0
regressor_saude_polinomial.intercept_
# Out:
# 16561.97463791193

# %%
# b1 (n)
regressor_saude_polinomial.coef_
# Out:
# array([ 0.00000000e+00, -2.12242253e+03,  9.90404199e+01, -1.95058276e+00,
#         1.40792541e-02])

# %%
novo = [[40]]

# %%
novo = poly.transform(novo)
novo
# Out:
# array([[1.00e+00, 4.00e+01, 1.60e+03, 6.40e+04, 2.56e+06]])

# %%
regressor_saude_polinomial.predict(novo)
# Out:
# array([1335.33958015])

# %%
previsoes = regressor_saude_polinomial.predict(X_plano_saude2_poly)
previsoes
# Out:
# array([ 549.65035464,  345.85081575,  616.53845992,  975.8391595 ,
#        1249.06759853, 1472.7272727 , 1894.51048941, 2973.2983677 ,
#        5379.16083828, 9993.35664357])

# %%
grafico = px.scatter(x = X_plano_saude2[:,0], y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2[:,0], y = previsoes, name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="659d35d4-1c76-4d8d-8b9f-e8664263fcad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("659d35d4-1c76-4d8d-8b9f-e8664263fcad")) {                    Plotly.newPlot(                        "659d35d4-1c76-4d8d-8b9f-e8664263fcad",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[549.6503546413369,345.8508157539454,616.5384599200042,975.8391594997865,1249.0675985260023,1472.7272727036961,1894.5104894104443,2973.298367696063,5379.160838282856,9993.356643565616],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5 ...

# %% [markdown]
# ## Base preço das casas - MAE 101.225, 0.81

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_teste.shape
# Out:
# (6484, 16)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)
X_casas_treinamento_poly = poly.fit_transform(X_casas_treinamento)
X_casas_teste_poly = poly.transform(X_casas_teste)

# %%
X_casas_treinamento_poly.shape, X_casas_teste_poly.shape
# Out:
# ((15129, 153), (6484, 153))

# %%
regressor_casas_poly = LinearRegression()
regressor_casas_poly.fit(X_casas_treinamento_poly, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
regressor_casas_poly.score(X_casas_treinamento_poly, y_casas_treinamento)
# Out:
# 0.4624797527477408

# %%
regressor_casas_poly.score(X_casas_teste_poly, y_casas_teste)
# Out:
# 0.45587085170531905

# %%
previsoes = regressor_casas_poly.predict(X_casas_teste_poly)
previsoes
# Out:
# array([2.6361433 , 3.77762266, 2.66739222, ..., 3.44794817, 3.08671102,
#        2.91989414])

# %%
y_casas_teste
# Out:
# array([2, 4, 2, ..., 3, 3, 3])

# %%
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 0.4992073754305287

# %% [markdown]
# # Árvores de decisão

# %% [markdown]
# ## Base plano saúde

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
from sklearn.tree import DecisionTreeRegressor
regressor_arvore_saude = DecisionTreeRegressor()
regressor_arvore_saude.fit(X_plano_saude2, y_plano_saude2)
# Out:
# DecisionTreeRegressor()

# %%
previsoes = regressor_arvore_saude.predict(X_plano_saude2)
previsoes
# Out:
# array([  470.,   520.,   630.,   830.,  1150.,  1530.,  2040.,  3080.,
#         5100., 10100.])

# %%
regressor_arvore_saude.score(X_plano_saude2, y_plano_saude2)
# Out:
# 1.0

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = previsoes, name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="175d2c56-b628-44bb-b3f8-c895bfec1ed2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("175d2c56-b628-44bb-b3f8-c895bfec1ed2")) {                    Plotly.newPlot(                        "175d2c56-b628-44bb-b3f8-c895bfec1ed2",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[470.0,520.0,630.0,830.0,1150.0,1530.0,2040.0,3080.0,5100.0,10100.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay"," ...

# %%
X_teste_arvore = np.arange(min(X_plano_saude2), max(X_plano_saude2), 0.1)
X_teste_arvore
# Out:
# <ipython-input-96-09c963292261>:1: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# array([18. , 18.1, 18.2, 18.3, 18.4, 18.5, 18.6, 18.7, 18.8, 18.9, 19. ,
#        19.1, 19.2, 19.3, 19.4, 19.5, 19.6, 19.7, 19.8, 19.9, 20. , 20.1,
#        20.2, 20.3, 20.4, 20.5, 20.6, 20.7, 20.8, 20.9, 21. , 21.1, 21.2,
#        21.3, 21.4, 21.5, 21.6, 21.7, 21.8, 21.9, 22. , 22.1, 22.2, 22.3,
#        22.4, 22.5, 22.6, 22.7, 22.8, 22.9, 23. , 23.1, 23.2, 23.3, 23.4,
#        23.5, 23.6, 23.7, 23.8, 23.9, 24. , 24.1, 24.2, 24.3, 24.4, 24.5,
#        24.6, 24.7, 24.8, 24.9, 25. , 25.1, 25.2, 25.3, 25.4, 25.5, 25.6,
#        25.7, 25.8, 25.9, 26. , 26.1, 26.2, 26.3, 26.4, 26.5, 26.6, 26.7,
#        26.8, 26.9, 27. , 27.1, 27.2, 27.3, 27.4, 27.5, 27.6, 27.7, 27.8,
#        27.9, 28. , 28.1, 28.2, 28.3, 28.4, 28.5, 28.6, 28.7, 28.8, 28.9,
#        29. , 29.1, 29.2, 29.3, 29.4, 29.5, 29.6, 29.7, 29.8, 29.9, 30. ,
#        30.1, 30.2, 30.3, 30.4, 30.5, 30.6, 30.7, 30.8, 30.9, 31. , 31.1,
#        31.2, 31.3, 31.4, 31.5, 31.6, 31.7, 31.8, 31.9, 32. , 32.1, 32.2,
#        32.3, 32.4, 32.5, 32.6, 32.7, 32.8, 32.9, 33. , 33.1, 33.2, 33.3,
#        33.4, 33.5, 33.6, 33.7, 33.8, 33.9, 34. , 34.1, 34.2, 34.3, 34.4,
#        34.5, 34.6, 34.7, 34.8, 34.9, 35. , 35.1, 35.2, 35.3, 35.4, 35.5,
#        35.6, 35.7, 35.8, 35.9, 36. , 36.1, 36.2, 36.3, 36.4, 36.5, 36.6,
#        36.7, 36.8, 36.9, 37. , 37.1, 37.2, 37.3, 37.4, 37.5, 37.6, 37.7,
#        37.8, 37.9, 38. , 38.1, 38.2, 38.3, 38.4, 38.5, 38.6, 38.7, 38.8,
#        38.9, 39. , 39.1, 39.2, 39.3, 39.4, 39.5, 39.6, 39.7, 39.8, 39.9,
#        40. , 40.1, 40.2, 40.3, 40.4, 40.5, 40.6, 40.7, 40.8, 40.9, 41. ,
#        41.1, 41.2, 41.3, 41.4, 41.5, 41.6, 41.7, 41.8, 41.9, 42. , 42.1,
#        42.2, 42.3, 42.4, 42.5, 42.6, 42.7, 42.8, 42.9, 43. , 43.1, 43.2,
#        43.3, 43.4, 43.5, 43.6, 43.7, 43.8, 43.9, 44. , 44.1, 44.2, 44.3,
#        44.4, 44.5, 44.6, 44.7, 44.8, 44.9, 45. , 45.1, 45.2, 45.3, 45.4,
#        45.5, 45.6, 45.7, 45.8, 45.9, 46. , 46.1, 46.2, 46.3, 46.4, 46.5,
#        46.6, 46.7, 46.8, 46.9, 47. , 47.1, 47.2, 47.3, 47.4, 47.5, 47.6,
#        47.7, 47.8, 47.9, 48. , 48.1, 48.2, 48.3, 48.4, 48.5, 48.6, 48.7,
#        48.8, 48.9, 49. , 49.1, 49.2, 49.3, 49.4, 49.5, 49.6, 49.7, 49.8,
#        49.9, 50. , 50.1, 50.2, 50.3, 50.4, 50.5, 50.6, 50.7, 50.8, 50.9,
#        51. , 51.1, 51.2, 51.3, 51.4, 51.5, 51.6, 51.7, 51.8, 51.9, 52. ,
#        52.1, 52.2, 52.3, 52.4, 52.5, 52.6, 52.7, 52.8, 52.9, 53. , 53.1,
#        53.2, 53.3, 53.4, 53.5, 53.6, 53.7, 53.8, 53.9, 54. , 54.1, 54.2,
#        54.3, 54.4, 54.5, 54.6, 54.7, 54.8, 54.9, 55. , 55.1, 55.2, 55.3,
#        55.4, 55.5, 55.6, 55.7, 55.8, 55.9, 56. , 56.1, 56.2, 56.3, 56.4,
#        56.5, 56.6, 56.7, 56.8, 56.9, 57. , 57.1, 57.2, 57.3, 57.4, 57.5,
#        57.6, 57.7, 57.8, 57.9, 58. , 58.1, 58.2, 58.3, 58.4, 58.5, 58.6,
#        58.7, 58.8, 58.9, 59. , 59.1, 59.2, 59.3, 59.4, 59.5, 59.6, 59.7,
#        59.8, 59.9, 60. , 60.1, 60.2, 60.3, 60.4, 60.5, 60.6, 60.7, 60.8,
#        60.9, 61. , 61.1, 61.2, 61.3, 61.4, 61.5, 61.6, 61.7, 61.8, 61.9,
#        62. , 62.1, 62.2, 62.3, 62.4, 62.5, 62.6, 62.7, 62.8, 62.9])

# %%
X_teste_arvore.shape
# Out:
# (450,)

# %%
X_teste_arvore = X_teste_arvore.reshape(-1,1)
X_teste_arvore.shape
# Out:
# (450, 1)

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_teste_arvore.ravel(), y = regressor_arvore_saude.predict(X_teste_arvore), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="77bea7e2-3e0a-42a9-b00a-6bff0a888b47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77bea7e2-3e0a-42a9-b00a-6bff0a888b47")) {                    Plotly.newPlot(                        "77bea7e2-3e0a-42a9-b00a-6bff0a888b47",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18.0,18.1,18.200000000000003,18.300000000000004,18.400000000000006,18.500000000000007,18.60000000000001,18.70000000000001,18.80000000000001,18.900000000000013,19.000000000000014,19.100000000000016,19.200000000000017,19.30000000000002,19.40000000000002,19.50000000000002,19.600000000000023,19.700000000000024,19.800000000000026,19.900000000000027,20.00000000000003,20.10000000000003,20.20000000000003,20.300000000000033,20.400000000000034,20.500000000000036,20.600000000000037,20.70000000000004,20.80000000000004,20.90000000000004,21.000000000000043,21.100000000000044,21.200000000000045,21.300000000000047,21.40000000000005,21.50000000000005,21.60000000000005,21.700000000000053,21.800000000000054,21.900000000000055,22.000000000000057,22.10000000000006,22.20000000000006,22.30000000000006,22.400000000000063,22.500000000000064,22.600000000000065,22.700000000000067,22.800000000000068,22.90000000000007,23.00000000000007,23.100000000000072,23.200000000000074,23.300000000000075,23.400000000000077,23.500000000000078,23.60000000000008,23.70000000000008,23.800000000000082,23.900000000000084,24.000000000000085,24.100000000000087,24.200000000000088,24.30000000000009,24.40000000000009,24.500000000000092,24.600000000000094,24.700000000000095,24.800000000000097,24.900000000000098,25.0000000000001,25.1000000000001,25.200000000000102,25.300000000000104,25.400000000000105,25.500000000000107,25.600000000000108,25.70000000000011,25.80000000000011,25.900000000000112,26.000000000000114,26.100000000000115,26.200000000000117,26.300000000000118,26.40000000000012,26.50000000000012,26.600000000000122,26.700000000000124,26.800000000000125,26.900000000000126,27.000000000000128,27.10000000000013,27.20000000000013,27.300000000000132,27.400000000000134,27.500000000000135,27.600000000000136,27.700000000000138,27.80000000000014,27.90000000000014,28.000000000000142,28.100000000000144,28.200000000000145,28.300000000000146,28.400000000000148,28.50000000000015,28.60000000000015,28.700000000000152,28.800000000000153,28.900000000000155,29.000000000000156,29.100000000000158,29.20000000000016,29.30000000000016,29.400000000000162,29.500000000000163,29.600000000000165,29.700000000000166,29.800000000000168,29.90000000000017,30.00000000000017,30.100000000000172,30.200000000000173,30.300000000000175,30.400000000000176,30.500000000000178,30.60000000000018,30.70000000000018,30.800000000000182,30.900000000000183,31.000000000000185,31.100000000000186,31.200000000000188,31.30000000000019,31.40000000000019,31.500000000000192,31.600000000000193,31.700000000000195,31.800000000000196,31.900000000000198,32.0000000000002,32.1000000000002,32.2000000000002,32.3000000000002,32.400000000000205,32.500000000000206,32.60000000000021,32.70000000000021,32.80000000000021,32.90000000000021,33.00000000000021,33.100000000000215,33.200000000000216,33.30000000000022,33.40000000000022,33.50000000000022,33.60000000000022,33.70000000000022,33.800000000000225,33.900000000000226,34.00000000000023,34.10000000000023,34.20000000000023,34.30000000000023,34.40000000000023,34.500000000000234,34.6 ...

# %%
regressor_arvore_saude.predict([[40.6]])
# Out:
# array([1530.])

# %% [markdown]
# ## Base preço das casas - MAE 99.917, 0.73

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento
# Out:
# array([[ 1.50000e+00,  1.39000e+03,  7.20000e+03, ...,  4.77224e+01,
#         -1.22332e+02,  1.63000e+03],
#        [ 1.50000e+00,  1.45000e+03,  7.31600e+03, ...,  4.77725e+01,
#         -1.22349e+02,  1.44000e+03],
#        [ 2.75000e+00,  2.86000e+03,  5.37900e+03, ...,  4.77082e+01,
#         -1.22104e+02,  2.98000e+03],
#        ...,
#        [ 2.25000e+00,  2.36000e+03,  1.49500e+04, ...,  4.73856e+01,
#         -1.22158e+02,  2.72000e+03],
#        [ 2.00000e+00,  2.37000e+03,  7.66650e+04, ...,  4.72831e+01,
#         -1.22279e+02,  2.11000e+03],
#        [ 2.25000e+00,  2.38000e+03,  1.62360e+04, ...,  4.76126e+01,
#         -1.22120e+02,  2.23000e+03]])

# %%
y_casas_treinamento
# Out:
# array([4, 3, 5, ..., 3, 4, 4])

# %%
X_casas_teste.shape
# Out:
# (6484, 16)

# %%
regressor_arvore_casas = DecisionTreeRegressor()
regressor_arvore_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# DecisionTreeRegressor()

# %%
regressor_arvore_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 1.0

# %%
regressor_arvore_casas.score(X_casas_teste, y_casas_teste)
# Out:
# -0.04126940733164197

# %%
previsoes = regressor_arvore_casas.predict(X_casas_teste)
previsoes
# Out:
# array([0., 4., 2., ..., 3., 3., 3.])

# %%
y_casas_teste
# Out:
# array([2, 4, 2, ..., 3, 3, 3])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 0.5640037014188772

# %% [markdown]
# # Random forest

# %% [markdown]
# ## Base plano de saúde

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_random_forest_saude = RandomForestRegressor(n_estimators = 10)
regressor_random_forest_saude.fit(X_plano_saude2, y_plano_saude2)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
regressor_random_forest_saude.score(X_plano_saude2, y_plano_saude2)
# Out:
# 0.9955432700355803

# %%
X_teste_arvore
# Out:
# array([[18. ],
#        [18.1],
#        [18.2],
#        [18.3],
#        [18.4],
#        [18.5],
#        [18.6],
#        [18.7],
#        [18.8],
#        [18.9],
#        [19. ],
#        [19.1],
#        [19.2],
#        [19.3],
#        [19.4],
#        [19.5],
#        [19.6],
#        [19.7],
#        [19.8],
#        [19.9],
#        [20. ],
#        [20.1],
#        [20.2],
#        [20.3],
#        [20.4],
#        [20.5],
#        [20.6],
#        [20.7],
#        [20.8],
#        [20.9],
#        [21. ],
#        [21.1],
#        [21.2],
#        [21.3],
#        [21.4],
#        [21.5],
#        [21.6],
#        [21.7],
#        [21.8],
#        [21.9],
#        [22. ],
#        [22.1],
#        [22.2],
#        [22.3],
#        [22.4],
#        [22.5],
#        [22.6],
#        [22.7],
#        [22.8],
#        [22.9],
#        [23. ],
#        [23.1],
#        [23.2],
#        [23.3],
#        [23.4],
#        [23.5],
#        [23.6],
#        [23.7],
#        [23.8],
#        [23.9],
#        [24. ],
#        [24.1],
#        [24.2],
#        [24.3],
#        [24.4],
#        [24.5],
#        [24.6],
#        [24.7],
#        [24.8],
#        [24.9],
#        [25. ],
#        [25.1],
#        [25.2],
#        [25.3],
#        [25.4],
#        [25.5],
#        [25.6],
#        [25.7],
#        [25.8],
#        [25.9],
#        [26. ],
#        [26.1],
#        [26.2],
#        [26.3],
#        [26.4],
#        [26.5],
#        [26.6],
#        [26.7],
#        [26.8],
#        [26.9],
#        [27. ],
#        [27.1],
#        [27.2],
#        [27.3],
#        [27.4],
#        [27.5],
#        [27.6],
#        [27.7],
#        [27.8],
#        [27.9],
#        [28. ],
#        [28.1],
#        [28.2],
#        [28.3],
#        [28.4],
#        [28.5],
#        [28.6],
#        [28.7],
#        [28.8],
#        [28.9],
#        [29. ],
#        [29.1],
#        [29.2],
#        [29.3],
#        [29.4],
#        [29.5],
#        [29.6],
#        [29.7],
#        [29.8],
#        [29.9],
#        [30. ],
#        [30.1],
#        [30.2],
#        [30.3],
#        [30.4],
#        [30.5],
#        [30.6],
#        [30.7],
#        [30.8],
#        [30.9],
#        [31. ],
#        [31.1],
#        [31.2],
#        [31.3],
#        [31.4],
#        [31.5],
#        [31.6],
#        [31.7],
#        [31.8],
#        [31.9],
#        [32. ],
#        [32.1],
#        [32.2],
#        [32.3],
#        [32.4],
#        [32.5],
#        [32.6],
#        [32.7],
#        [32.8],
#        [32.9],
#        [33. ],
#        [33.1],
#        [33.2],
#        [33.3],
#        [33.4],
#        [33.5],
#        [33.6],
#        [33.7],
#        [33.8],
#        [33.9],
#        [34. ],
#        [34.1],
#        [34.2],
#        [34.3],
#        [34.4],
#        [34.5],
#        [34.6],
#        [34.7],
#        [34.8],
#        [34.9],
#        [35. ],
#        [35.1],
#        [35.2],
#        [35.3],
#        [35.4],
#        [35.5],
#        [35.6],
#        [35.7],
#        [35.8],
#        [35.9],
#        [36. ],
#        [36.1],
#        [36.2],
#        [36.3],
#        [36.4],
#        [36.5],
#        [36.6],
#        [36.7],
#        [36.8],
#        [36.9],
#        [37. ],
#        [37.1],
#        [37.2],
#        [37.3],
#        [37.4],
#        [37.5],
#        [37.6],
#        [37.7],
#        [37.8],
#        [37.9],
#        [38. ],
#        [38.1],
#        [38.2],
#        [38.3],
#        [38.4],
#        [38.5],
#        [38.6],
#        [38.7],
#        [38.8],
#        [38.9],
#        [39. ],
#        [39.1],
#        [39.2],
#        [39.3],
#        [39.4],
#        [39.5],
#        [39.6],
#        [39.7],
#        [39.8],
#        [39.9],
#        [40. ],
#        [40.1],
#        [40.2],
#        [40.3],
#        [40.4],
#        [40.5],
#        [40.6],
#        [40.7],
#        [40.8],
#        [40.9],
#        [41. ],
#        [41.1],
#        [41.2],
#        [41.3],
#        [41.4],
#        [41.5],
#        [41.6],
#        [41.7],
#        [41.8],
#        [41.9],
#        [42. ],
#        [42.1],
#        [42.2],
#        [42.3],
#        [42.4],
#        [42.5],
#        [42.6],
#        [42.7],
#        [42.8],
#        [42.9],
#        [43. ],
#        [43.1],
#        [43.2],
#        [43.3],
#        [43.4],
#        [43.5],
#        [43.6],
#        [43.7],
#        [43.8],
#        [43.9],
#        [44. ],
#        [44.1],
#        [44.2],
#        [44.3],
#        [44.4],
#        [44.5],
#        [44.6],
#        [44.7],
#        [44.8],
#        [44.9],
#        [45. ],
#        [45.1],
#        [45.2],
#        [45.3],
#        [45.4],
#        [45.5],
#        [45.6],
#        [45.7],
#        [45.8],
#        [45.9],
#        [46. ],
#        [46.1],
#        [46.2],
#        [46.3],
#        [46.4],
#        [46.5],
#        [46.6],
#        [46.7],
#        [46.8],
#        [46.9],
#        [47. ],
#        [47.1],
#        [47.2],
#        [47.3],
#        [47.4],
#        [47.5],
#        [47.6],
#        [47.7],
#        [47.8],
#        [47.9],
#        [48. ],
#        [48.1],
#        [48.2],
#        [48.3],
#        [48.4],
#        [48.5],
#        [48.6],
#        [48.7],
#        [48.8],
#        [48.9],
#        [49. ],
#        [49.1],
#        [49.2],
#        [49.3],
#        [49.4],
#        [49.5],
#        [49.6],
#        [49.7],
#        [49.8],
#        [49.9],
#        [50. ],
#        [50.1],
#        [50.2],
#        [50.3],
#        [50.4],
#        [50.5],
#        [50.6],
#        [50.7],
#        [50.8],
#        [50.9],
#        [51. ],
#        [51.1],
#        [51.2],
#        [51.3],
#        [51.4],
#        [51.5],
#        [51.6],
#        [51.7],
#        [51.8],
#        [51.9],
#        [52. ],
#        [52.1],
#        [52.2],
#        [52.3],
#        [52.4],
#        [52.5],
#        [52.6],
#        [52.7],
#        [52.8],
#        [52.9],
#        [53. ],
#        [53.1],
#        [53.2],
#        [53.3],
#        [53.4],
#        [53.5],
#        [53.6],
#        [53.7],
#        [53.8],
#        [53.9],
#        [54. ],
#        [54.1],
#        [54.2],
#        [54.3],
#        [54.4],
#        [54.5],
#        [54.6],
#        [54.7],
#        [54.8],
#        [54.9],
#        [55. ],
#        [55.1],
#        [55.2],
#        [55.3],
#        [55.4],
#        [55.5],
#        [55.6],
#        [55.7],
#        [55.8],
#        [55.9],
#        [56. ],
#        [56.1],
#        [56.2],
#        [56.3],
#        [56.4],
#        [56.5],
#        [56.6],
#        [56.7],
#        [56.8],
#        [56.9],
#        [57. ],
#        [57.1],
#        [57.2],
#        [57.3],
#        [57.4],
#        [57.5],
#        [57.6],
#        [57.7],
#        [57.8],
#        [57.9],
#        [58. ],
#        [58.1],
#        [58.2],
#        [58.3],
#        [58.4],
#        [58.5],
#        [58.6],
#        [58.7],
#        [58.8],
#        [58.9],
#        [59. ],
#        [59.1],
#        [59.2],
#        [59.3],
#        [59.4],
#        [59.5],
#        [59.6],
#        [59.7],
#        [59.8],
#        [59.9],
#        [60. ],
#        [60.1],
#        [60.2],
#        [60.3],
#        [60.4],
#        [60.5],
#        [60.6],
#        [60.7],
#        [60.8],
#        [60.9],
#        [61. ],
#        [61.1],
#        [61.2],
#        [61.3],
#        [61.4],
#        [61.5],
#        [61.6],
#        [61.7],
#        [61.8],
#        [61.9],
#        [62. ],
#        [62.1],
#        [62.2],
#        [62.3],
#        [62.4],
#        [62.5],
#        [62.6],
#        [62.7],
#        [62.8],
#        [62.9]])

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_teste_arvore.ravel(), y = regressor_random_forest_saude.predict(X_teste_arvore), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bc746a29-3568-4bd0-8ceb-07b05c1815d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc746a29-3568-4bd0-8ceb-07b05c1815d3")) {                    Plotly.newPlot(                        "bc746a29-3568-4bd0-8ceb-07b05c1815d3",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18.0,18.1,18.200000000000003,18.300000000000004,18.400000000000006,18.500000000000007,18.60000000000001,18.70000000000001,18.80000000000001,18.900000000000013,19.000000000000014,19.100000000000016,19.200000000000017,19.30000000000002,19.40000000000002,19.50000000000002,19.600000000000023,19.700000000000024,19.800000000000026,19.900000000000027,20.00000000000003,20.10000000000003,20.20000000000003,20.300000000000033,20.400000000000034,20.500000000000036,20.600000000000037,20.70000000000004,20.80000000000004,20.90000000000004,21.000000000000043,21.100000000000044,21.200000000000045,21.300000000000047,21.40000000000005,21.50000000000005,21.60000000000005,21.700000000000053,21.800000000000054,21.900000000000055,22.000000000000057,22.10000000000006,22.20000000000006,22.30000000000006,22.400000000000063,22.500000000000064,22.600000000000065,22.700000000000067,22.800000000000068,22.90000000000007,23.00000000000007,23.100000000000072,23.200000000000074,23.300000000000075,23.400000000000077,23.500000000000078,23.60000000000008,23.70000000000008,23.800000000000082,23.900000000000084,24.000000000000085,24.100000000000087,24.200000000000088,24.30000000000009,24.40000000000009,24.500000000000092,24.600000000000094,24.700000000000095,24.800000000000097,24.900000000000098,25.0000000000001,25.1000000000001,25.200000000000102,25.300000000000104,25.400000000000105,25.500000000000107,25.600000000000108,25.70000000000011,25.80000000000011,25.900000000000112,26.000000000000114,26.100000000000115,26.200000000000117,26.300000000000118,26.40000000000012,26.50000000000012,26.600000000000122,26.700000000000124,26.800000000000125,26.900000000000126,27.000000000000128,27.10000000000013,27.20000000000013,27.300000000000132,27.400000000000134,27.500000000000135,27.600000000000136,27.700000000000138,27.80000000000014,27.90000000000014,28.000000000000142,28.100000000000144,28.200000000000145,28.300000000000146,28.400000000000148,28.50000000000015,28.60000000000015,28.700000000000152,28.800000000000153,28.900000000000155,29.000000000000156,29.100000000000158,29.20000000000016,29.30000000000016,29.400000000000162,29.500000000000163,29.600000000000165,29.700000000000166,29.800000000000168,29.90000000000017,30.00000000000017,30.100000000000172,30.200000000000173,30.300000000000175,30.400000000000176,30.500000000000178,30.60000000000018,30.70000000000018,30.800000000000182,30.900000000000183,31.000000000000185,31.100000000000186,31.200000000000188,31.30000000000019,31.40000000000019,31.500000000000192,31.600000000000193,31.700000000000195,31.800000000000196,31.900000000000198,32.0000000000002,32.1000000000002,32.2000000000002,32.3000000000002,32.400000000000205,32.500000000000206,32.60000000000021,32.70000000000021,32.80000000000021,32.90000000000021,33.00000000000021,33.100000000000215,33.200000000000216,33.30000000000022,33.40000000000022,33.50000000000022,33.60000000000022,33.70000000000022,33.800000000000225,33.900000000000226,34.00000000000023,34.10000000000023,34.20000000000023,34.30000000000023,34.40000000000023,34.500000000000234,34.6 ...

# %%
regressor_random_forest_saude.predict([[40]])
# Out:
# array([1393.])

# %% [markdown]
# ## Base preço das casas - MAE 67.615, 0.88

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento
# Out:
# array([[ 1.50000e+00,  1.39000e+03,  7.20000e+03, ...,  4.77224e+01,
#         -1.22332e+02,  1.63000e+03],
#        [ 1.50000e+00,  1.45000e+03,  7.31600e+03, ...,  4.77725e+01,
#         -1.22349e+02,  1.44000e+03],
#        [ 2.75000e+00,  2.86000e+03,  5.37900e+03, ...,  4.77082e+01,
#         -1.22104e+02,  2.98000e+03],
#        ...,
#        [ 2.25000e+00,  2.36000e+03,  1.49500e+04, ...,  4.73856e+01,
#         -1.22158e+02,  2.72000e+03],
#        [ 2.00000e+00,  2.37000e+03,  7.66650e+04, ...,  4.72831e+01,
#         -1.22279e+02,  2.11000e+03],
#        [ 2.25000e+00,  2.38000e+03,  1.62360e+04, ...,  4.76126e+01,
#         -1.22120e+02,  2.23000e+03]])

# %%
y_casas_treinamento
# Out:
# array([4, 3, 5, ..., 3, 4, 4])

# %%
X_casas_teste
# Out:
# array([[ 1.50000e+00,  1.43000e+03,  1.65000e+03, ...,  4.77222e+01,
#         -1.22290e+02,  1.43000e+03],
#        [ 3.25000e+00,  4.67000e+03,  5.18360e+04, ...,  4.76350e+01,
#         -1.22164e+02,  4.23000e+03],
#        [ 7.50000e-01,  1.44000e+03,  3.70000e+03, ...,  4.76707e+01,
#         -1.22364e+02,  1.44000e+03],
#        ...,
#        [ 2.50000e+00,  2.15000e+03,  2.57050e+04, ...,  4.74514e+01,
#         -1.22089e+02,  1.85000e+03],
#        [ 1.75000e+00,  1.48000e+03,  8.00900e+03, ...,  4.73657e+01,
#         -1.22280e+02,  1.79000e+03],
#        [ 1.00000e+00,  1.32000e+03,  9.23900e+03, ...,  4.73120e+01,
#         -1.22183e+02,  1.32000e+03]])

# %%
regressor_random_forest_casas = RandomForestRegressor(n_estimators=100)
regressor_random_forest_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# RandomForestRegressor()

# %%
regressor_random_forest_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.9301877877118329

# %%
regressor_random_forest_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.5006985367314093

# %%
previsoes = regressor_random_forest_casas.predict(X_casas_teste)
previsoes
# Out:
# array([1.15, 4.1 , 2.64, ..., 3.19, 3.1 , 2.99])

# %%
y_casas_teste
# Out:
# array([2, 4, 2, ..., 3, 3, 3])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 0.4591533004318322

# %% [markdown]
# # SVM

# %% [markdown]
# ## Base plano de saúde

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
# Kernel linear
from sklearn.svm import SVR
regressor_svr_saude_linear = SVR(kernel = 'linear')
regressor_svr_saude_linear.fit(X_plano_saude2, y_plano_saude2)
# Out:
# SVR(kernel='linear')

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = regressor_svr_saude_linear.predict(X_plano_saude2), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6680d9f9-8771-4f8e-b515-bc1ddb20b325" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6680d9f9-8771-4f8e-b515-bc1ddb20b325")) {                    Plotly.newPlot(                        "6680d9f9-8771-4f8e-b515-bc1ddb20b325",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[216.14000000000033,520.0999999999999,824.0600000000004,1128.0199999999995,1431.9800000000005,1735.9399999999996,2039.8999999999996,2343.8599999999997,2647.8200000000006,2951.7799999999997],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"# ...

# %%
# Kernel polinomial
regressor_svr_saude_poly = SVR(kernel='poly', degree=4)
regressor_svr_saude_poly.fit(X_plano_saude2, y_plano_saude2)
# Out:
# SVR(degree=4, kernel='poly')

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = regressor_svr_saude_poly.predict(X_plano_saude2), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="67610a6f-cafc-436f-9458-71e5ecb41319" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67610a6f-cafc-436f-9458-71e5ecb41319")) {                    Plotly.newPlot(                        "67610a6f-cafc-436f-9458-71e5ecb41319",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[374.5071751819414,448.2086650497321,589.3253226432124,830.1001009540422,1209.098100619297,1771.2065699214809,2567.6349047885387,3655.9146487937624,5099.899493155958,6969.7652767393165],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f ...

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
from sklearn.preprocessing import StandardScaler
scaler_x = StandardScaler()
X_plano_saude2_scaled = scaler_x.fit_transform(X_plano_saude2)
scaler_y = StandardScaler()
y_plano_saude2_scaled = scaler_y.fit_transform(y_plano_saude2.reshape(-1,1))

# %%
X_plano_saude2_scaled
# Out:
# array([[-1.5666989 ],
#        [-1.21854359],
#        [-0.87038828],
#        [-0.52223297],
#        [-0.17407766],
#        [ 0.17407766],
#        [ 0.52223297],
#        [ 0.87038828],
#        [ 1.21854359],
#        [ 1.5666989 ]])

# %%
y_plano_saude2_scaled
# Out:
# array([[-0.72401136],
#        [-0.7065653 ],
#        [-0.66818397],
#        [-0.59839975],
#        [-0.48674498],
#        [-0.35415495],
#        [-0.17620517],
#        [ 0.18667281],
#        [ 0.8914935 ],
#        [ 2.63609918]])

# %%
# Kernel rbf
regressor_svr_saude_rbf = SVR(kernel='rbf')
regressor_svr_saude_rbf.fit(X_plano_saude2_scaled, y_plano_saude2_scaled.ravel())
# Out:
# SVR()

# %%
grafico = px.scatter(x = X_plano_saude2_scaled.ravel(), y = y_plano_saude2_scaled.ravel())
grafico.add_scatter(x = X_plano_saude2_scaled.ravel(), y = regressor_svr_saude_rbf.predict(X_plano_saude2_scaled), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a55a6cca-37b1-40b6-90de-3430fd1416e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a55a6cca-37b1-40b6-90de-3430fd1416e6")) {                    Plotly.newPlot(                        "a55a6cca-37b1-40b6-90de-3430fd1416e6",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"xaxis":"x","y":[-0.7240113561520064,-0.7065652993772592,-0.6681839744728155,-0.598399747373827,-0.48674498401544525,-0.354154952527367,-0.17620517342494613,0.18667280748979442,0.8914935011895789,2.6360991786642933],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"y":[-0.6234807140772864,-0.6329127762510356,-0.5706650687442069,-0.4986650770824684,-0.4463759606657199,-0.36326796984014836,-0.13553889365913357,0.29353246308522923,0.7912281797991034,1.0938296800840372],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556, ...

# %%
novo = [[40]]

# %%
novo = scaler_x.transform(novo)
novo
# Out:
# array([[-0.03481553]])

# %%
#scaler_y.inverse_transform(regressor_svr_saude_rbf.predict(novo)) -- Atualizado 17/08/2022 -- Inclusão .reshape(-1, 1)

# %%
scaler_y.inverse_transform(regressor_svr_saude_rbf.predict(novo).reshape(-1, 1))
# Out:
# array([[1333.85650748]])

# %% [markdown]
# ## Base preço das casas - MAE 82.453, 0.73

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento
# Out:
# array([[ 1.50000e+00,  1.39000e+03,  7.20000e+03, ...,  4.77224e+01,
#         -1.22332e+02,  1.63000e+03],
#        [ 1.50000e+00,  1.45000e+03,  7.31600e+03, ...,  4.77725e+01,
#         -1.22349e+02,  1.44000e+03],
#        [ 2.75000e+00,  2.86000e+03,  5.37900e+03, ...,  4.77082e+01,
#         -1.22104e+02,  2.98000e+03],
#        ...,
#        [ 2.25000e+00,  2.36000e+03,  1.49500e+04, ...,  4.73856e+01,
#         -1.22158e+02,  2.72000e+03],
#        [ 2.00000e+00,  2.37000e+03,  7.66650e+04, ...,  4.72831e+01,
#         -1.22279e+02,  2.11000e+03],
#        [ 2.25000e+00,  2.38000e+03,  1.62360e+04, ...,  4.76126e+01,
#         -1.22120e+02,  2.23000e+03]])

# %%
y_casas_treinamento
# Out:
# array([4, 3, 5, ..., 3, 4, 4])

# %%
X_casas_teste.shape
# Out:
# (6484, 16)

# %%
from sklearn.preprocessing import StandardScaler
scaler_x_casas = StandardScaler()
X_casas_treinamento_scaled = scaler_x_casas.fit_transform(X_casas_treinamento)
scaler_y_casas = StandardScaler()
y_casas_treinamento_scaled = scaler_y_casas.fit_transform(y_casas_treinamento.reshape(-1,1))

# %%
X_casas_treinamento_scaled
# Out:
# array([[-0.79711466, -0.74522967, -0.19007787, ...,  1.17348387,
#         -0.83797629, -0.51711194],
#        [-0.79711466, -0.68028398, -0.18732779, ...,  1.53476983,
#         -0.95879989, -0.7940208 ],
#        [ 0.82292131,  0.84593978, -0.23324948, ...,  1.07108346,
#          0.78248142,  1.45039839],
#        ...,
#        [ 0.17490692,  0.30472568, -0.0063437 , ..., -1.25528083,
#          0.3986888 ,  1.07147047],
#        [-0.14910028,  0.31554996,  1.45677304, ..., -1.99443873,
#         -0.46129094,  0.18244729],
#        [ 0.17490692,  0.32637425,  0.02414432, ...,  0.38168351,
#          0.66876509,  0.35733709]])

# %%
y_casas_treinamento_scaled
# Out:
# array([[ 0.67170039],
#        [-0.38696772],
#        [ 1.7303685 ],
#        ...,
#        [-0.38696772],
#        [ 0.67170039],
#        [ 0.67170039]])

# %%
X_casas_treinamento_scaled.shape, y_casas_treinamento_scaled.shape
# Out:
# ((15129, 16), (15129, 1))

# %%
X_casas_teste_scaled = scaler_x_casas.transform(X_casas_teste)
y_casas_teste_scaled = scaler_y_casas.transform(y_casas_teste.reshape(-1,1))

# %%
X_casas_teste_scaled.shape, y_casas_teste_scaled.shape
# Out:
# ((6484, 16), (6484, 1))

# %%
X_casas_teste_scaled
# Out:
# array([[-0.79711466, -0.70193254, -0.32165525, ...,  1.17204161,
#         -0.53947092, -0.80859495],
#        [ 1.47093569,  2.80513482,  0.86813615, ...,  0.54321655,
#          0.35604518,  3.2721672 ],
#        [-1.76913625, -0.69110826, -0.2730546 , ...,  0.80065984,
#         -1.06540895, -0.7940208 ],
#        ...,
#        [ 0.49891411,  0.07741576,  0.24863193, ..., -0.78077751,
#          0.88909048, -0.19648063],
#        [-0.47310747, -0.64781113, -0.1708984 , ..., -1.39878563,
#         -0.46839822, -0.28392553],
#        [-1.44512905, -0.82099964, -0.141738  , ..., -1.78603226,
#          0.22100704, -0.96891061]])

# %%
y_casas_teste_scaled
# Out:
# array([[-1.44563583],
#        [ 0.67170039],
#        [-1.44563583],
#        ...,
#        [-0.38696772],
#        [-0.38696772],
#        [-0.38696772]])

# %%
regressor_svr_casas = SVR(kernel='rbf')
regressor_svr_casas.fit(X_casas_treinamento_scaled, y_casas_treinamento_scaled.ravel())
# Out:
# SVR()

# %%
regressor_svr_casas.score(X_casas_treinamento_scaled, y_casas_treinamento_scaled)
# Out:
# 0.5186203340757594

# %%
regressor_svr_casas.score(X_casas_teste_scaled, y_casas_teste_scaled)
# Out:
# 0.4812255272111644

# %%
#previsoes = regressor_svr_casas.predict(X_casas_teste_scaled) -- Atualizado 17/08/2022 -- Inclusão .reshape(-1, 1)
#previsoes

# %%
previsoes = regressor_svr_casas.predict(X_casas_teste_scaled).reshape(-1, 1)
previsoes
# Out:
# array([[-0.84641751],
#        [ 0.79473338],
#        [-1.19596549],
#        ...,
#        [ 0.08202457],
#        [-0.31736935],
#        [-0.32641521]])

# %%
y_casas_teste_scaled
# Out:
# array([[-1.44563583],
#        [ 0.67170039],
#        [-1.44563583],
#        ...,
#        [-0.38696772],
#        [-0.38696772],
#        [-0.38696772]])

# %%
y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled)
previsoes_inverse = scaler_y_casas.inverse_transform(previsoes)

# %%
y_casas_teste_inverse
# Out:
# array([[2.],
#        [4.],
#        [2.],
#        ...,
#        [3.],
#        [3.],
#        [3.]])

# %%
previsoes_inverse
# Out:
# array([[2.56601149],
#        [4.11621488],
#        [2.23583439],
#        ...,
#        [3.44300219],
#        [3.06574144],
#        [3.05719688]])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste_inverse, previsoes_inverse)
# Out:
# 0.4644150068381374

# %% [markdown]
# # Redes neurais artificiais

# %% [markdown]
# ## Base plano de saúde

# %%
X_plano_saude2_scaled
# Out:
# array([[-1.5666989 ],
#        [-1.21854359],
#        [-0.87038828],
#        [-0.52223297],
#        [-0.17407766],
#        [ 0.17407766],
#        [ 0.52223297],
#        [ 0.87038828],
#        [ 1.21854359],
#        [ 1.5666989 ]])

# %%
y_plano_saude2_scaled
# Out:
# array([[-0.72401136],
#        [-0.7065653 ],
#        [-0.66818397],
#        [-0.59839975],
#        [-0.48674498],
#        [-0.35415495],
#        [-0.17620517],
#        [ 0.18667281],
#        [ 0.8914935 ],
#        [ 2.63609918]])

# %%
from sklearn.neural_network import MLPRegressor
regressor_rna_saude = MLPRegressor(max_iter=1000)
regressor_rna_saude.fit(X_plano_saude2_scaled, y_plano_saude2_scaled.ravel())
# Out:
# MLPRegressor(max_iter=1000)

# %%
regressor_rna_saude.score(X_plano_saude2_scaled, y_plano_saude2_scaled)
# Out:
# 0.9556824975464481

# %%
grafico = px.scatter(x = X_plano_saude2_scaled.ravel(), y = y_plano_saude2_scaled.ravel())
grafico.add_scatter(x = X_plano_saude2_scaled.ravel(), y = regressor_rna_saude.predict(X_plano_saude2_scaled), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f60ad25a-6799-4b43-bd49-c5e268147cb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f60ad25a-6799-4b43-bd49-c5e268147cb5")) {                    Plotly.newPlot(                        "f60ad25a-6799-4b43-bd49-c5e268147cb5",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"xaxis":"x","y":[-0.7240113561520064,-0.7065652993772592,-0.6681839744728155,-0.598399747373827,-0.48674498401544525,-0.354154952527367,-0.17620517342494613,0.18667280748979442,0.8914935011895789,2.6360991786642933],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"y":[-0.7591775976115341,-0.6946872933491353,-0.6331796493086789,-0.5771039396278552,-0.5284726688184438,-0.46415957738611724,-0.20023120211527048,0.40498701640743084,1.2836455501274606,2.1625438300125204],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556, ...

# %%
novo = [[40]]
novo = scaler_x.transform(novo)
novo
# Out:
# array([[-0.03481553]])

# %%
##scaler_y.inverse_transform(regressor_rna_saude.predict(novo)) -- Atualizado 17/08/2022 -- Inclusão .reshape(-1, 1)

# %%
scaler_y.inverse_transform(regressor_rna_saude.predict(novo).reshape(-1, 1))
# Out:
# array([[1073.9051209]])

# %% [markdown]
# ## Base preço das casas - MAE 76.311, 0.87

# %%
X_casas_treinamento_scaled.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento_scaled
# Out:
# array([[-0.79711466, -0.74522967, -0.19007787, ...,  1.17348387,
#         -0.83797629, -0.51711194],
#        [-0.79711466, -0.68028398, -0.18732779, ...,  1.53476983,
#         -0.95879989, -0.7940208 ],
#        [ 0.82292131,  0.84593978, -0.23324948, ...,  1.07108346,
#          0.78248142,  1.45039839],
#        ...,
#        [ 0.17490692,  0.30472568, -0.0063437 , ..., -1.25528083,
#          0.3986888 ,  1.07147047],
#        [-0.14910028,  0.31554996,  1.45677304, ..., -1.99443873,
#         -0.46129094,  0.18244729],
#        [ 0.17490692,  0.32637425,  0.02414432, ...,  0.38168351,
#          0.66876509,  0.35733709]])

# %%
y_casas_treinamento_scaled
# Out:
# array([[ 0.67170039],
#        [-0.38696772],
#        [ 1.7303685 ],
#        ...,
#        [-0.38696772],
#        [ 0.67170039],
#        [ 0.67170039]])

# %%
X_casas_teste_scaled.shape
# Out:
# (6484, 16)

# %%
(16 + 1) / 2
# Out:
# 8.5

# %%
# 16 -> 9 -> 9 -> 1
regressor_rna_casas = MLPRegressor(max_iter=1000, hidden_layer_sizes=(9,9))
regressor_rna_casas.fit(X_casas_treinamento_scaled, y_casas_treinamento_scaled.ravel())
# Out:
# MLPRegressor(hidden_layer_sizes=(9, 9), max_iter=1000)

# %%
regressor_rna_casas.score(X_casas_treinamento_scaled, y_casas_treinamento_scaled)
# Out:
# 0.4891728838177565

# %%
regressor_rna_casas.score(X_casas_teste_scaled, y_casas_teste_scaled)
# Out:
# 0.48339690080669095

# %%
##previsoes = regressor_rna_casas.predict(X_casas_teste_scaled) -- Atualizado 17/08/2022 -- Inclusão .reshape(-1, 1)
##previsoes

# %%
previsoes = regressor_rna_casas.predict(X_casas_teste_scaled).reshape(-1, 1)
previsoes
# Out:
# array([[-0.76941642],
#        [ 0.68560929],
#        [-0.57034353],
#        ...,
#        [ 0.61097255],
#        [-0.20946781],
#        [-0.38624325]])

# %%
y_casas_teste_scaled
# Out:
# array([[-1.44563583],
#        [ 0.67170039],
#        [-1.44563583],
#        ...,
#        [-0.38696772],
#        [-0.38696772],
#        [-0.38696772]])

# %%
y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled)
previsoes_inverse = scaler_y_casas.inverse_transform(previsoes)

# %%
y_casas_teste_inverse
# Out:
# array([[2.],
#        [4.],
#        [2.],
#        ...,
#        [3.],
#        [3.],
#        [3.]])

# %%
previsoes_inverse
# Out:
# array([[2.63874543],
#        [4.01313811],
#        [2.82678632],
#        ...,
#        [3.94263751],
#        [3.16766341],
#        [3.00068432]])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste_inverse, previsoes_inverse)
# Out:
# 0.4808823432783821
